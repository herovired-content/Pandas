# %%
import os, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
os.chdir('D:\Work\B2B\Aditya Group\Module 02 Lectures\Lecture 02')
df = pd.read_csv('bank_data.csv',sep=';')
df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
sns.histplot(df['day']);

# %%
#sns.histplot

# %%
sns.histplot(df['day'],bins=30);

# %%
#df['day']>30

# %%
sum(df['day']>=30)
# Out:
# 227

# %%
sum(df['day']<5)
# Out:
# 385

# %%
sns.histplot(df['day'],cumulative=True);

# %%
sns.histplot(df['day'],cumulative=True,stat='probability');

# %% [markdown]
# ### Getting count of unique values in a Categorical variable

# %%
df['day'].nunique()
# Out:
# 31

# %% [markdown]
# ### Getting unique values in a Categorical variable

# %%
df['day'].unique()
# Out:
# array([19, 11, 16,  3,  5, 23, 14,  6, 17, 20, 13, 30, 29, 27,  7, 18, 12,
#        21, 26, 22,  2,  4, 15,  8, 28,  9,  1, 10, 31, 25, 24],
#       dtype=int64)

# %%
df['balance'].nunique()
# Out:
# 2353

# %% [markdown]
# ## Creating Sample DataFrame using Dictionary

# %%
import random
dic = { 'Class':[random.choice(['10th Std','11th Std','12th Std']) for i in range(7)],
       'Rollno':random.sample(range(10,30),7),
       'Gender':[random.choice(['M','F']) for i in range(7)],
      'English':[random.randint(10,100) for i in range(7)],
      'Physics':[random.randint(10,100) for i in range(7)],
    'Chemistry':[random.randint(10,100) for i in range(7)],
  'Scholorship':[random.choice([True,False]) for i in range(7)]}
df = pd.DataFrame(dic)
df
# Out:
#       Class  Rollno Gender  English  Physics  Chemistry  Scholorship
# 0  10th Std      19      M       44       50         21         True
# 1  11th Std      26      F       41       82         76        False
# 2  12th Std      13      M       39       61         73        False
# 3  10th Std      25      M       38       58         47         True
# 4  10th Std      15      M       35       18         70        False
# 5  10th Std      29      F       56       73         53         True
# 6  11th Std      22      M       59       97         64         True

# %%
df['Chemistry']>80
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: Chemistry, dtype: bool

# %%
sum(df['Chemistry']>80)
# Out:
# 0

# %%
df.head(3)
# Out:
#       Class  Rollno Gender  English  Physics  Chemistry  Scholorship
# 0  10th Std      19      M       44       50         21         True
# 1  11th Std      26      F       41       82         76        False
# 2  12th Std      13      M       39       61         73        False

# %%
os.chdir('D:\Work\B2B\Aditya Group\Module 02 Lectures\Lecture 02')
df = pd.read_csv('bank_data.csv',sep=';')
df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %% [markdown]
# # Applying Multiple Criteria on a DataFrame

# %%
criteria_1 = df['balance'] > 1000
criteria_2 = df['poutcome'] == 'success'
criteria_3 = df['job'].isin(['management','retired','entrepreneur'])

# %%
df['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
criteria_3.sum()
# Out:
# 1367

# %%
plt.figure(figsize=(18,7))
sns.countplot(data=df, x='job');

# %%
plt.figure(figsize=(18,7))
sns.countplot(df['job']);
# Out:
# D:\mysoftwares\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %% [markdown]
# #### Applying the three criteria with AND conditions

# %%
criteria_1 & criteria_2 & criteria_3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# Length: 4521, dtype: bool

# %%
sum(criteria_1 & criteria_2 & criteria_3)
# Out:
# 19

# %%
#----------Checking the shape of sub-set DataFrame-----------
df[criteria_1 & criteria_2 & criteria_3].shape
# Out:
# (19, 17)

# %%
df[criteria_1 & criteria_2 & criteria_3]
# Out:
#       age           job  marital  education default  balance housing loan  \
# 199    75       retired  married  secondary      no     3771      no   no
# 323    38    management  married   tertiary      no     1199      no   no
# 338    63       retired  married    primary      no     1084      no   no
# 347    55    management  married    primary      no     2587      no   no
# 477    77       retired  married   tertiary      no     7802      no   no
# 1056   63  entrepreneur  married  secondary      no     3904      no   no
# 1060   48    management  married   tertiary      no     1147      no   no
# 1216   29    management   single   tertiary      no    15459      no   no
# 1303   42    management  married    unknown      no     1519      no   no
# 1442   73       retired  married    primary      no     1388      no   no
# 1754   29    management   single   tertiary      no     1445      no   no
# 2070   80       retired  married  secondary      no     8304      no   no
# 3202   79       retired  married    primary      no     8556      no   no
# 3331   53    management  married    unknown      no     2240     yes   no
# 3589   38    management  married    unknown      no     3576      no   no
# 3695   31    management  married   tertiary      no     1331      no   no
# 3978   66       retired  married   tertiary      no     1948      no   no
# 4093   69       retired   single   tertiary      no     2144      no   no
# 4160   57       retired  married  secondary      no     1044      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 199   telephone   15   apr       185         1    181         2  success  yes
# 323    cellular    4   aug       178         1      1         1  success  yes
# 338    cellular   14   oct       201         1    183         1  success   no
# 347    cellular    4   sep       328         2     94         2  success  yes
# 477   telephone    4   may       421         1     92         2  success  yes
# 1056  telephone    4   aug       250         2    187         2  success  yes
# 1060   cellular    5   aug       389         1     64         2  success  yes
# 1216   cellular   26   may       245         3     97         7  success   no
# 1303   cellular   19   oct       230         1     92         1  success  yes
# 1442   cellular   20   jul       146         3    190         3  success   no
# 1754   cellular   26   apr       328         2    143         2  success  yes
# 2070  telephone    6   apr       681         1    118        11  success   no
# 3202  telephone   18   jan       326         2    272         2  success  yes
# 3331   cellular    2   jun       282         2    385         1  success  yes
# 3589   cellular   25   nov       349         2    183         1  success  yes
# 3695   cellular   30   apr       297         1     86         3  success  yes
# 3978   cellular   28   jan       216         1     91         4  success  yes
# 4093   cellular   29   jul       417         1    184         4  success  yes
# 4160  telephone   11   jan       585         1    192         2  success  yes

# %% [markdown]
# ### Varying how the three criteria can be applied

# %%
sum(criteria_1 & criteria_2 | criteria_3)
# Out:
# 1409

# %%
sum(criteria_1 | criteria_2 & criteria_3)
# Out:
# 1499

# %%
sum(criteria_1 | (criteria_2 & criteria_3) )
# Out:
# 1499

# %%
sum(criteria_1 & (criteria_2 | criteria_3) )
# Out:
# 558

# %% [markdown]
# ## Creating a sub-set DataFrame

# %%
subset_1 = df[criteria_1 & criteria_2 & criteria_3]
subset_1.shape
# Out:
# (19, 17)

# %%
subset_1.head(3)
# Out:
#      age         job  marital  education default  balance housing loan  \
# 199   75     retired  married  secondary      no     3771      no   no
# 323   38  management  married   tertiary      no     1199      no   no
# 338   63     retired  married    primary      no     1084      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 199  telephone   15   apr       185         1    181         2  success  yes
# 323   cellular    4   aug       178         1      1         1  success  yes
# 338   cellular   14   oct       201         1    183         1  success   no

# %%
subset_1['y']
# Out:
# 199     yes
# 323     yes
# 338      no
# 347     yes
# 477     yes
# 1056    yes
# 1060    yes
# 1216     no
# 1303    yes
# 1442     no
# 1754    yes
# 2070     no
# 3202    yes
# 3331    yes
# 3589    yes
# 3695    yes
# 3978    yes
# 4093    yes
# 4160    yes
# Name: y, dtype: object

# %%
subset_1['y'].value_counts()
# Out:
# yes    15
# no      4
# Name: y, dtype: int64

# %%
subset_1['y'].value_counts(normalize=True)
# Out:
# yes    0.789474
# no     0.210526
# Name: y, dtype: float64

# %%
subset_1.head()
# Out:
#      age         job  marital  education default  balance housing loan  \
# 199   75     retired  married  secondary      no     3771      no   no
# 323   38  management  married   tertiary      no     1199      no   no
# 338   63     retired  married    primary      no     1084      no   no
# 347   55  management  married    primary      no     2587      no   no
# 477   77     retired  married   tertiary      no     7802      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 199  telephone   15   apr       185         1    181         2  success  yes
# 323   cellular    4   aug       178         1      1         1  success  yes
# 338   cellular   14   oct       201         1    183         1  success   no
# 347   cellular    4   sep       328         2     94         2  success  yes
# 477  telephone    4   may       421         1     92         2  success  yes

# %% [markdown]
# #### Viewing just the relevant columns in this Subset

# %%
subset_1[['duration','campaign','pdays','poutcome','previous','y']]
# Out:
#       duration  campaign  pdays poutcome  previous    y
# 199        185         1    181  success         2  yes
# 323        178         1      1  success         1  yes
# 338        201         1    183  success         1   no
# 347        328         2     94  success         2  yes
# 477        421         1     92  success         2  yes
# 1056       250         2    187  success         2  yes
# 1060       389         1     64  success         2  yes
# 1216       245         3     97  success         7   no
# 1303       230         1     92  success         1  yes
# 1442       146         3    190  success         3   no
# 1754       328         2    143  success         2  yes
# 2070       681         1    118  success        11   no
# 3202       326         2    272  success         2  yes
# 3331       282         2    385  success         1  yes
# 3589       349         2    183  success         1  yes
# 3695       297         1     86  success         3  yes
# 3978       216         1     91  success         4  yes
# 4093       417         1    184  success         4  yes
# 4160       585         1    192  success         2  yes

# %% [markdown]
# #### Another way

# %%
my_cols = ['duration','campaign','pdays','poutcome','previous','y']
subset_1[my_cols]
# Out:
#       duration  campaign  pdays poutcome  previous    y
# 199        185         1    181  success         2  yes
# 323        178         1      1  success         1  yes
# 338        201         1    183  success         1   no
# 347        328         2     94  success         2  yes
# 477        421         1     92  success         2  yes
# 1056       250         2    187  success         2  yes
# 1060       389         1     64  success         2  yes
# 1216       245         3     97  success         7   no
# 1303       230         1     92  success         1  yes
# 1442       146         3    190  success         3   no
# 1754       328         2    143  success         2  yes
# 2070       681         1    118  success        11   no
# 3202       326         2    272  success         2  yes
# 3331       282         2    385  success         1  yes
# 3589       349         2    183  success         1  yes
# 3695       297         1     86  success         3  yes
# 3978       216         1     91  success         4  yes
# 4093       417         1    184  success         4  yes
# 4160       585         1    192  success         2  yes

# %%
subset_1.head()
# Out:
#      age         job  marital  education default  balance housing loan  \
# 199   75     retired  married  secondary      no     3771      no   no
# 323   38  management  married   tertiary      no     1199      no   no
# 338   63     retired  married    primary      no     1084      no   no
# 347   55  management  married    primary      no     2587      no   no
# 477   77     retired  married   tertiary      no     7802      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 199  telephone   15   apr       185         1    181         2  success  yes
# 323   cellular    4   aug       178         1      1         1  success  yes
# 338   cellular   14   oct       201         1    183         1  success   no
# 347   cellular    4   sep       328         2     94         2  success  yes
# 477  telephone    4   may       421         1     92         2  success  yes

# %% [markdown]
# #### Following selection of Columns is not possible

# %%
subset_1[['duration':'y']]
# Out:
#   File "<ipython-input-43-65551036183d>", line 1
#     subset_1[['duration':'y']]
#                         ^
# SyntaxError: invalid syntax

# %%
subset_1['duration':'y']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7f4b79d3474d> in <module>
# ----> 1 subset_1['duration':'y']
#
# D:\mysoftwares\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2997
#    2998         # Do we have a slicer (on rows)?
# -> 2999         indexer = convert_to_index_sliceable(self, key)
#    3000         if indexer is not None:
#    3001             if isinstance(indexer, np.ndarray):
#
# D:\mysoftwares\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2208     idx = obj.index
#    2209     if isinstance(key, slice):
# -> 2210         return idx._convert_slice_indexer(key, kind="getitem")
#    2211
#    2212     elif isinstance(key, str):
#
# D:\mysoftwares\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    3354             """
#    3355             if self.is_integer() or is_index_slice:
# -> 3356                 self._validate_indexer("slice", key.start, "getitem")
#    3357                 self._validate_indexer("slice", key.stop, "getitem")
#    3358                 self._validate_indexer("slice", key.step, "getitem")
#
# D:\mysoftwares\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    5307             pass
#    5308         else:
# -> 5309             raise self._invalid_indexer(form, key)
#    5310
#    5311     def _maybe_cast_slice_bound(self, label, side: str_t, kind):
#
# TypeError: cannot do slice indexing on Int64Index with these indexers [duration] of type str

# %% [markdown]
# # Indexer .loc (and .iloc)

# %%
#-------------subset_1[['duration':'y']]

# %%
df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %% [markdown]
# #### Single row selection using .loc Indexer - Gives a Series with DataFrame Header as Index

# %%
df.loc[10]
# Out:
# age                 39
# job           services
# marital        married
# education    secondary
# default             no
# balance           9374
# housing            yes
# loan                no
# contact        unknown
# day                 20
# month              may
# duration           273
# campaign             1
# pdays               -1
# previous             0
# poutcome       unknown
# y                   no
# Name: 10, dtype: object

# %% [markdown]
# #### Multiple rows selection (Range) using .loc Indexer

# %%
df.loc[10:14]
# Out:
#     age          job  marital  education default  balance housing loan  \
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
# 12   36   technician  married   tertiary      no     1109      no   no
# 13   20      student   single  secondary      no      502      no   no
# 14   31  blue-collar  married  secondary      no      360     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 10   unknown   20   may       273         1     -1         0  unknown   no
# 11  cellular   17   apr       113         2     -1         0  unknown   no
# 12  cellular   13   aug       328         2     -1         0  unknown   no
# 13  cellular   30   apr       261         1     -1         0  unknown  yes
# 14  cellular   29   jan        89         1    241         1  failure   no

# %% [markdown]
# #### Multiple rows selection (Discrete) using .loc Indexer

# %%
df.loc[[90,1,0,34]]
# Out:
#     age          job  marital  education default  balance housing loan  \
# 90   39  blue-collar  married    primary      no      111      no   no
# 1    33     services  married  secondary      no     4789     yes  yes
# 0    30   unemployed  married    primary      no     1787      no   no
# 34   49   technician  married   tertiary      no     1235      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 90  cellular   18   nov       201         2     -1         0  unknown   no
# 1   cellular   11   may       220         1    339         4  failure   no
# 0   cellular   19   oct        79         1     -1         0  unknown   no
# 34  cellular   13   aug       354         3     -1         0  unknown  yes

# %% [markdown]
# #### Single column selection using .loc Indexer

# %%
df.loc[:,'y']
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 4516    no
# 4517    no
# 4518    no
# 4519    no
# 4520    no
# Name: y, Length: 4521, dtype: object

# %% [markdown]
# #### Multiple columns (discrete) selection using .loc indexer

# %%
df.loc[:,['age','education','pdays','job']]
# Out:
#       age  education  pdays            job
# 0      30    primary     -1     unemployed
# 1      33  secondary    339       services
# 2      35   tertiary    330     management
# 3      30   tertiary     -1     management
# 4      59  secondary     -1    blue-collar
# ...   ...        ...    ...            ...
# 4516   33  secondary     -1       services
# 4517   57   tertiary     -1  self-employed
# 4518   57  secondary     -1     technician
# 4519   28  secondary    211    blue-collar
# 4520   44   tertiary    249   entrepreneur
#
# [4521 rows x 4 columns]

# %% [markdown]
# #### Multiple columns (range) selection using .loc indexer

# %%
df.loc[:,'age':'education']
# Out:
#       age            job  marital  education
# 0      30     unemployed  married    primary
# 1      33       services  married  secondary
# 2      35     management   single   tertiary
# 3      30     management  married   tertiary
# 4      59    blue-collar  married  secondary
# ...   ...            ...      ...        ...
# 4516   33       services  married  secondary
# 4517   57  self-employed  married   tertiary
# 4518   57     technician  married  secondary
# 4519   28    blue-collar  married  secondary
# 4520   44   entrepreneur   single   tertiary
#
# [4521 rows x 4 columns]

# %% [markdown]
# #### Multiple Rows and Multiple Columns selection using .loc Indexer

# %%
df.loc[[90,1,0,34],['age','education','pdays','job']]
# Out:
#     age  education  pdays          job
# 90   39    primary     -1  blue-collar
# 1    33  secondary    339     services
# 0    30    primary     -1   unemployed
# 34   49   tertiary     -1   technician

# %%
df.loc[5:10,['age','education','pdays','job']]
# Out:
#     age  education  pdays            job
# 5    35   tertiary    176     management
# 6    36   tertiary    330  self-employed
# 7    39  secondary     -1     technician
# 8    41   tertiary     -1   entrepreneur
# 9    43    primary    147       services
# 10   39  secondary     -1       services

# %% [markdown]
# # Simple operations on Variables of different type (for Self-Study)
# * Numeric
# * Object/String
# * Dates

# %%
os.chdir('D:\Work\B2B\Aditya Group\Module 02 Lectures\Lecture 04')

# %%
edf = pd.read_csv('hrdata.csv')
edf.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary_previous  \
# 0            1       5            4                       0            52139
# 1            5       3            3                       0            93546
# 2            5       5            3                       0            61278
# 3            1       5            3                       0            62828
# 4            5       5            3                       0            49663
#
#    ...     ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# 0  ...  Michael Albert       22.0           LinkedIn          Exceeds
# 1  ...      Simon Roup        4.0             Indeed      Fully Meets
# 2  ...  Kissy Sullivan       20.0           LinkedIn      Fully Meets
# 3  ...    Elijiah Gray       16.0             Indeed      Fully Meets
# 4  ...  Webster Butler       39.0      Google Search      Fully Meets
#
#   EngagementSurvey  EmpSatisfaction SpecialProjectsCount  \
# 0             4.60                5                    0
# 1             4.96                3                    6
# 2             3.02                3                    0
# 3             4.84                5                    0
# 4             5.00                4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                 01-03-2019              0       15
# 4                 02-01-2016              0        2
#
# [5 rows x 37 columns]

# %%
#-----------To display all the columns in the DataFrame----------
pd.set_option("display.max_columns", None)

# %%
edf.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary_previous  \
# 0            1       5            4                       0            52139
# 1            5       3            3                       0            93546
# 2            5       5            3                       0            61278
# 3            1       5            3                       0            62828
# 4            5       5            3                       0            49663
#
#    Salary_current  Termd  PositionID                  Position State   Zip  \
# 0           62506      0          19   Production Technician I    MA  1960
# 1          104437      1          27                   Sr. DBA    MA  2148
# 2           64955      1          20  Production Technician II    MA  1810
# 3           64991      0          19   Production Technician I    MA  1886
# 4           50825      1          19   Production Technician I    MA  2169
#
#           DOB Sex MaritalDesc CitizenDesc HispanicLatino RaceDesc  DateofHire  \
# 0  07-10-1983  M       Single  US Citizen             No    White  07-05-2011
# 1  05-05-1975  M      Married  US Citizen             No    White   3/30/2015
# 2    09/19/88   F     Married  US Citizen             No    White  07-05-2011
# 3    09/27/88   F     Married  US Citizen             No    White  01-07-2008
# 4  09-08-1989   F    Divorced  US Citizen             No    White  07-11-2011
#
#   DateofTermination         TermReason        EmploymentStatus  \
# 0               NaN  N/A-StillEmployed                  Active
# 1         6/16/2016      career change  Voluntarily Terminated
# 2         9/24/2012              hours  Voluntarily Terminated
# 3               NaN  N/A-StillEmployed                  Active
# 4        09-06-2016   return to school  Voluntarily Terminated
#
#           Department     ManagerName  ManagerID RecruitmentSource  \
# 0  Production         Michael Albert       22.0          LinkedIn
# 1              IT/IS      Simon Roup        4.0            Indeed
# 2  Production         Kissy Sullivan       20.0          LinkedIn
# 3  Production           Elijiah Gray       16.0            Indeed
# 4  Production         Webster Butler       39.0     Google Search
#
#   PerformanceScore  EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0          Exceeds              4.60                5                     0
# 1      Fully Meets              4.96                3                     6
# 2      Fully Meets              3.02                3                     0
# 3      Fully Meets              4.84                5                     0
# 4      Fully Meets              5.00                4                     0
#
#   LastPerformanceReview_Date  DaysLateLast30  Absences
# 0                  1/17/2019               0         1
# 1                  2/24/2016               0        17
# 2                  5/15/2012               0         3
# 3                 01-03-2019               0        15
# 4                 02-01-2016               0         2

# %%
#---------Viewing how variables have been read (notice the dtype of Date Variables)-----------
edf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary_previous             311 non-null    int64
#  10  Salary_current              311 non-null    int64
#  11  Termd                       311 non-null    int64
#  12  PositionID                  311 non-null    int64
#  13  Position                    311 non-null    object
#  14  State                       311 non-null    object
#  15  Zip                         311 non-null    int64
#  16  DOB                         311 non-null    object
#  17  Sex                         311 non-null    object
#  18  MaritalDesc                 311 non-null    object
#  19  CitizenDesc                 311 non-null    object
#  20  HispanicLatino              311 non-null    object
#  21  RaceDesc                    311 non-null    object
#  22  DateofHire                  311 non-null    object
#  23  DateofTermination           104 non-null    object
#  24  TermReason                  311 non-null    object
#  25  EmploymentStatus            311 non-null    object
#  26  Department                  311 non-null    object
#  27  ManagerName                 311 non-null    object
#  28  ManagerID                   303 non-null    float64
#  29  RecruitmentSource           311 non-null    object
#  30  PerformanceScore            311 non-null    object
#  31  EngagementSurvey            311 non-null    float64
#  32  EmpSatisfaction             311 non-null    int64
#  33  SpecialProjectsCount        311 non-null    int64
#  34  LastPerformanceReview_Date  311 non-null    object
#  35  DaysLateLast30              311 non-null    int64
#  36  Absences                    311 non-null    int64
# dtypes: float64(2), int64(17), object(18)
# memory usage: 90.0+ KB

# %% [markdown]
# ### Taking care of Dates variables - reading these as Proper dates

# %%
edf = pd.read_csv('hrdata.csv',parse_dates=['DOB','DateofHire','DateofTermination','LastPerformanceReview_Date'])

# %%
#--------Checking again the dtype of all variables (notice now, how the Date Variables have been read)-----------
#--------Dates show with dtype of datetime-------
edf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary_previous             311 non-null    int64
#  10  Salary_current              311 non-null    int64
#  11  Termd                       311 non-null    int64
#  12  PositionID                  311 non-null    int64
#  13  Position                    311 non-null    object
#  14  State                       311 non-null    object
#  15  Zip                         311 non-null    int64
#  16  DOB                         311 non-null    datetime64[ns]
#  17  Sex                         311 non-null    object
#  18  MaritalDesc                 311 non-null    object
#  19  CitizenDesc                 311 non-null    object
#  20  HispanicLatino              311 non-null    object
#  21  RaceDesc                    311 non-null    object
#  22  DateofHire                  311 non-null    datetime64[ns]
#  23  DateofTermination           104 non-null    datetime64[ns]
#  24  TermReason                  311 non-null    object
#  25  EmploymentStatus            311 non-null    object
#  26  Department                  311 non-null    object
#  27  ManagerName                 311 non-null    object
#  28  ManagerID                   303 non-null    float64
#  29  RecruitmentSource           311 non-null    object
#  30  PerformanceScore            311 non-null    object
#  31  EngagementSurvey            311 non-null    float64
#  32  EmpSatisfaction             311 non-null    int64
#  33  SpecialProjectsCount        311 non-null    int64
#  34  LastPerformanceReview_Date  311 non-null    datetime64[ns]
#  35  DaysLateLast30              311 non-null    int64
#  36  Absences                    311 non-null    int64
# dtypes: datetime64[ns](4), float64(2), int64(17), object(14)
# memory usage: 90.0+ KB

# %% [markdown]
# ## Operations on Numeric variables

# %%
#--------------Viewing only the Numeric variables-------------
edf.select_dtypes(include='number')
# Out:
#      EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  \
# 0    10026          0                0         1            1       5
# 1    10084          1                1         1            5       3
# 2    10196          1                1         0            5       5
# 3    10088          1                1         0            1       5
# 4    10069          0                2         0            5       5
# ..     ...        ...              ...       ...          ...     ...
# 306  10135          0                0         1            1       5
# 307  10301          0                0         0            5       5
# 308  10010          0                0         0            1       3
# 309  10043          0                0         0            1       3
# 310  10271          0                4         0            1       5
#
#      PerfScoreID  FromDiversityJobFairID  Salary_previous  Salary_current  \
# 0              4                       0            52139           62506
# 1              3                       0            93546          104437
# 2              3                       0            61278           64955
# 3              3                       0            62828           64991
# 4              3                       0            49663           50825
# ..           ...                     ...              ...             ...
# 306            3                       0            53105           65893
# 307            1                       0            42212           48513
# 308            4                       0           184376          220450
# 309            3                       0            77745           89292
# 310            3                       0            41001           45046
#
#      Termd  PositionID   Zip  ManagerID  EngagementSurvey  EmpSatisfaction  \
# 0        0          19  1960       22.0              4.60                5
# 1        1          27  2148        4.0              4.96                3
# 2        1          20  1810       20.0              3.02                3
# 3        0          19  1886       16.0              4.84                5
# 4        1          19  2169       39.0              5.00                4
# ..     ...         ...   ...        ...               ...              ...
# 306      0          20  1810       20.0              4.07                4
# 307      1          19  2458       12.0              3.20                2
# 308      0           6  2067        2.0              4.60                5
# 309      0           9  2148        4.0              5.00                3
# 310      0          19  1730       14.0              4.50                5
#
#      SpecialProjectsCount  DaysLateLast30  Absences
# 0                       0               0         1
# 1                       6               0        17
# 2                       0               0         3
# 3                       0               0        15
# 4                       0               0         2
# ..                    ...             ...       ...
# 306                     0               0        13
# 307                     0               5         4
# 308                     6               0        16
# 309                     5               0        11
# 310                     0               0         2
#
# [311 rows x 19 columns]

# %% [markdown]
# ### 01. Simple Addition
# * Scalar 100 gets added to all the values in Series

# %%
edf['Salary_current']+100
# Out:
# 0       62606
# 1      104537
# 2       65055
# 3       65091
# 4       50925
#         ...
# 306     65993
# 307     48613
# 308    220550
# 309     89392
# 310     45146
# Name: Salary_current, Length: 311, dtype: int64

# %% [markdown]
# ### 02. Simple Division

# %%
edf['Salary_current']/12
# Out:
# 0       5208.833333
# 1       8703.083333
# 2       5412.916667
# 3       5415.916667
# 4       4235.416667
#            ...
# 306     5491.083333
# 307     4042.750000
# 308    18370.833333
# 309     7441.000000
# 310     3753.833333
# Name: Salary_current, Length: 311, dtype: float64

# %% [markdown]
# ### 03. Simple Difference

# %%
edf['Salary_current']-edf['Salary_previous']
# Out:
# 0      10367
# 1      10891
# 2       3677
# 3       2163
# 4       1162
#        ...
# 306    12788
# 307     6301
# 308    36074
# 309    11547
# 310     4045
# Length: 311, dtype: int64

# %% [markdown]
# ### 04. Multiple operations

# %%
(edf['Salary_current']-edf['Salary_previous'])/edf['Salary_previous']
# Out:
# 0      0.198834
# 1      0.116424
# 2      0.060005
# 3      0.034427
# 4      0.023398
#          ...
# 306    0.240806
# 307    0.149270
# 308    0.195655
# 309    0.148524
# 310    0.098656
# Length: 311, dtype: float64

# %% [markdown]
# ## Operations on Object/ String variables
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html

# %%
#--------------Viewing only the Numeric variables-------------
edf.select_dtypes(include='object').head()
# Out:
#               Employee_Name                  Position State Sex MaritalDesc  \
# 0       Adinolfi, Wilson  K   Production Technician I    MA  M       Single
# 1  Ait Sidi, Karthikeyan                      Sr. DBA    MA  M      Married
# 2         Akinkuolie, Sarah  Production Technician II    MA   F     Married
# 3              Alagbe,Trina   Production Technician I    MA   F     Married
# 4          Anderson, Carol    Production Technician I    MA   F    Divorced
#
#   CitizenDesc HispanicLatino RaceDesc         TermReason  \
# 0  US Citizen             No    White  N/A-StillEmployed
# 1  US Citizen             No    White      career change
# 2  US Citizen             No    White              hours
# 3  US Citizen             No    White  N/A-StillEmployed
# 4  US Citizen             No    White   return to school
#
#          EmploymentStatus         Department     ManagerName  \
# 0                  Active  Production         Michael Albert
# 1  Voluntarily Terminated              IT/IS      Simon Roup
# 2  Voluntarily Terminated  Production         Kissy Sullivan
# 3                  Active  Production           Elijiah Gray
# 4  Voluntarily Terminated  Production         Webster Butler
#
#   RecruitmentSource PerformanceScore
# 0          LinkedIn          Exceeds
# 1            Indeed      Fully Meets
# 2          LinkedIn      Fully Meets
# 3            Indeed      Fully Meets
# 4     Google Search      Fully Meets

# %% [markdown]
# ### 01. Change to Upper Case
# * 'str' is an accessor object which allows access to the properties of an Object variable

# %%
edf['Department'].str.upper()
# Out:
# 0      PRODUCTION
# 1                  IT/IS
# 2      PRODUCTION
# 3      PRODUCTION
# 4      PRODUCTION
#              ...
# 306    PRODUCTION
# 307    PRODUCTION
# 308                IT/IS
# 309                IT/IS
# 310    PRODUCTION
# Name: Department, Length: 311, dtype: object

# %% [markdown]
# ### 02. Find length of string

# %%
edf['Employee_Name'].str.len()
# Out:
# 0      19
# 1      24
# 2      17
# 3      12
# 4      16
#        ..
# 306    14
# 307    18
# 308    16
# 309    11
# 310    13
# Name: Employee_Name, Length: 311, dtype: int64

# %% [markdown]
# ### 03. Concatenating Two string variables

# %%
edf['Employee_Name']+ " | " +edf['Position']
# Out:
# 0      Adinolfi, Wilson  K | Production Technician I
# 1                 Ait Sidi, Karthikeyan    | Sr. DBA
# 2       Akinkuolie, Sarah | Production Technician II
# 3             Alagbe,Trina | Production Technician I
# 4         Anderson, Carol  | Production Technician I
#                            ...
# 306        Woodson, Jason | Production Technician II
# 307     Ybarra, Catherine  | Production Technician I
# 308                           Zamora, Jennifer | CIO
# 309                       Zhou, Julia | Data Analyst
# 310          Zima, Colleen | Production Technician I
# Length: 311, dtype: object

# %% [markdown]
# ### 04. Splitting a single variable to multiple

# %%
(edf['Employee_Name']+ " | " +edf['Position']).str.split("|")
# Out:
# 0      [Adinolfi, Wilson  K ,  Production Technician I]
# 1                 [Ait Sidi, Karthikeyan    ,  Sr. DBA]
# 2       [Akinkuolie, Sarah ,  Production Technician II]
# 3             [Alagbe,Trina ,  Production Technician I]
# 4         [Anderson, Carol  ,  Production Technician I]
#                              ...
# 306        [Woodson, Jason ,  Production Technician II]
# 307     [Ybarra, Catherine  ,  Production Technician I]
# 308                           [Zamora, Jennifer ,  CIO]
# 309                       [Zhou, Julia ,  Data Analyst]
# 310          [Zima, Colleen ,  Production Technician I]
# Length: 311, dtype: object

# %% [markdown]
# #### By default, the splitted information is stored in a Series

# %%
type((edf['Employee_Name']+ " | " +edf['Position']).str.split("|"))
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### By using expand=True, the splitted information can be stored in Two separate variables (.i.e a DataFrame)

# %%
type((edf['Employee_Name']+ " | " +edf['Position']).str.split("|",expand=True))
# Out:
# pandas.core.frame.DataFrame

# %%
#-------------Viewing the output with expand=True---------
(edf['Employee_Name']+ " | " +edf['Position']).str.split("|",expand=True)
# Out:
#                              0                          1
# 0         Adinolfi, Wilson  K     Production Technician I
# 1    Ait Sidi, Karthikeyan                        Sr. DBA
# 2           Akinkuolie, Sarah    Production Technician II
# 3                Alagbe,Trina     Production Technician I
# 4            Anderson, Carol      Production Technician I
# ..                         ...                        ...
# 306            Woodson, Jason    Production Technician II
# 307        Ybarra, Catherine      Production Technician I
# 308          Zamora, Jennifer                         CIO
# 309               Zhou, Julia                Data Analyst
# 310             Zima, Colleen     Production Technician I
#
# [311 rows x 2 columns]

# %% [markdown]
# #### Creating an Empty DataFrame - .i.e with 0 rows and 0 columns

# %%
empty = pd.DataFrame()
empty.shape
# Out:
# (0, 0)

# %% [markdown]
# #### Storing the earlier splitted information as new variables in this empty DataFrame

# %%
empty[['Full Name','Position']] = (edf['Employee_Name']+ " | " +edf['Position']).str.split("|",expand=True)

# %%
empty.shape
# Out:
# (311, 2)

# %%
empty
# Out:
#                      Full Name                   Position
# 0         Adinolfi, Wilson  K     Production Technician I
# 1    Ait Sidi, Karthikeyan                        Sr. DBA
# 2           Akinkuolie, Sarah    Production Technician II
# 3                Alagbe,Trina     Production Technician I
# 4            Anderson, Carol      Production Technician I
# ..                         ...                        ...
# 306            Woodson, Jason    Production Technician II
# 307        Ybarra, Catherine      Production Technician I
# 308          Zamora, Jennifer                         CIO
# 309               Zhou, Julia                Data Analyst
# 310             Zima, Colleen     Production Technician I
#
# [311 rows x 2 columns]

# %% [markdown]
# ### 05. Replace a string

# %%
edf['TermReason'].head()
# Out:
# 0    N/A-StillEmployed
# 1        career change
# 2                hours
# 3    N/A-StillEmployed
# 4     return to school
# Name: TermReason, dtype: object

# %%
#---------------Replacing "N/A-" with empty space-------
edf['TermReason'].str.replace("N/A-","").head()
# Out:
# 0       StillEmployed
# 1       career change
# 2               hours
# 3       StillEmployed
# 4    return to school
# Name: TermReason, dtype: object

# %%
#-------------Adding extra space after the string "Still"--------
edf['TermReason'].str.replace("Still","Still ").head()
# Out:
# 0    N/A-Still Employed
# 1         career change
# 2                 hours
# 3    N/A-Still Employed
# 4      return to school
# Name: TermReason, dtype: object

# %% [markdown]
# ### 06. String that starts or Ends with a sub-string

# %%
edf[edf['Position'].str.startswith("Production")]['Position'].unique()
# Out:
# array(['Production Technician I', 'Production Technician II',
#        'Production Manager'], dtype=object)

# %% [markdown]
# ## Operations on Date variables

# %%
#--------------Viewing only the Datetime variables-------------
edf.select_dtypes(include='datetime').head()
#---------NaT means Not a Time---
# Out:
#          DOB DateofHire DateofTermination LastPerformanceReview_Date
# 0 1983-07-10 2011-07-05               NaT                 2019-01-17
# 1 1975-05-05 2015-03-30        2016-06-16                 2016-02-24
# 2 1988-09-19 2011-07-05        2012-09-24                 2012-05-15
# 3 1988-09-27 2008-01-07               NaT                 2019-01-03
# 4 1989-09-08 2011-07-11        2016-09-06                 2016-02-01

# %% [markdown]
# ### 01. Extracting the Year
# * 'dt' is an accessor object which allows access to the properties of a Datetime variable

# %%
edf['DOB'].dt.year
# Out:
# 0      1983
# 1      1975
# 2      1988
# 3      1988
# 4      1989
#        ...
# 306    1985
# 307    1982
# 308    1979
# 309    1979
# 310    1978
# Name: DOB, Length: 311, dtype: int64

# %% [markdown]
# ### 02. Extracting the Month

# %%
edf['DOB'].dt.month
# Out:
# 0      7
# 1      5
# 2      9
# 3      9
# 4      9
#       ..
# 306    5
# 307    5
# 308    8
# 309    2
# 310    8
# Name: DOB, Length: 311, dtype: int64

# %% [markdown]
# ### 03. Extracting the Day

# %%
edf['DOB'].dt.day
# Out:
# 0      10
# 1       5
# 2      19
# 3      27
# 4       8
#        ..
# 306    11
# 307     4
# 308    30
# 309    24
# 310    17
# Name: DOB, Length: 311, dtype: int64

# %% [markdown]
# ### 04. Creating a new variable with today's date

# %%
edf['today']=pd.to_datetime('today')

# %%
#---------------Viewing all date variables again----------
edf.select_dtypes(include='datetime').head()
# Out:
#          DOB DateofHire DateofTermination LastPerformanceReview_Date  \
# 0 1983-07-10 2011-07-05               NaT                 2019-01-17
# 1 1975-05-05 2015-03-30        2016-06-16                 2016-02-24
# 2 1988-09-19 2011-07-05        2012-09-24                 2012-05-15
# 3 1988-09-27 2008-01-07               NaT                 2019-01-03
# 4 1989-09-08 2011-07-11        2016-09-06                 2016-02-01
#
#                        today
# 0 2021-12-24 18:08:41.370225
# 1 2021-12-24 18:08:41.370225
# 2 2021-12-24 18:08:41.370225
# 3 2021-12-24 18:08:41.370225
# 4 2021-12-24 18:08:41.370225

# %% [markdown]
# ### 05. Creating a new column with any date

# %%
edf['somedate']=pd.to_datetime('2021-11-27',format="%Y-%m-%d")
edf.select_dtypes(include='datetime').head()
# Out:
#          DOB DateofHire DateofTermination LastPerformanceReview_Date  \
# 0 1983-07-10 2011-07-05               NaT                 2019-01-17
# 1 1975-05-05 2015-03-30        2016-06-16                 2016-02-24
# 2 1988-09-19 2011-07-05        2012-09-24                 2012-05-15
# 3 1988-09-27 2008-01-07               NaT                 2019-01-03
# 4 1989-09-08 2011-07-11        2016-09-06                 2016-02-01
#
#                        today   somedate
# 0 2021-12-24 18:08:41.370225 2021-11-27
# 1 2021-12-24 18:08:41.370225 2021-11-27
# 2 2021-12-24 18:08:41.370225 2021-11-27
# 3 2021-12-24 18:08:41.370225 2021-11-27
# 4 2021-12-24 18:08:41.370225 2021-11-27

# %% [markdown]
# ### 06. Computing dates difference

# %%
edf['today']-edf['DOB']
#------------This gives a timedelta object----
# Out:
# 0     14047 days 18:08:41.370225
# 1     17035 days 18:08:41.370225
# 2     12149 days 18:08:41.370225
# 3     12141 days 18:08:41.370225
# 4     11795 days 18:08:41.370225
#                  ...
# 306   13376 days 18:08:41.370225
# 307   14479 days 18:08:41.370225
# 308   15457 days 18:08:41.370225
# 309   15644 days 18:08:41.370225
# 310   15835 days 18:08:41.370225
# Length: 311, dtype: timedelta64[ns]

# %% [markdown]
# ### 07. Finding number of days from a Timedelta object

# %%
(edf['today']-edf['DOB']).dt.days
# Out:
# 0      14047
# 1      17035
# 2      12149
# 3      12141
# 4      11795
#        ...
# 306    13376
# 307    14479
# 308    15457
# 309    15644
# 310    15835
# Length: 311, dtype: int64
